# %%
import json
import time
import requests
from dotenv import load_dotenv
load_dotenv()

import os

OpenTrip_API = os.environ.get('OpenTripMap_API_key')

BASE_URL = 'http://api.opentripmap.com/0.1/en/places/radius'

# 建立基本函式查詢(以台北車站為中心，半徑1000公尺的景點查詢)

params = {
    'radius': 1000,
    'lon': 121.5170,
    'lat': 25.0478,
    'apikey': OpenTrip_API,
    'kinds': 'tourist_object',
    'limit': 20
}

response = requests.get(BASE_URL, params = params)
time.sleep(5)

# 如果程式狀態回應是200，那回應將會解析成json格式的數據，存在變數data中
if response.status_code == 200:
    data = response.json()
    # json.dumps將程式作用的對象(像是字典、列表)進行格式化輸出
    formatted_data = json.dumps(data, indent = 2, sort_keys = True, ensure_ascii = False) # ensure_asscii = False 可確保中文正常顯示。
else:
    print('Status code:', response.status_code)

print(formatted_data)
# Out:
# {}

# %%
import json
import time
import requests
from dotenv import load_dotenv
load_dotenv()

import os

OpenTrip_API = os.environ.get('OpenTripMap_API_key')

BASE_URL = 'https://api.opentripmap.com/0.1/en/places/radius'

# 建立基本函式查詢(以台北車站為中心，半徑2000公尺的景點查詢)

wanted_kinds = ['interesting_places', 'tourist_object', 'museums']
wanted_rates = [3, '3h']

params = {
    'radius': 2000,
    'lon': 121.5170,
    'lat': 25.0478,
    'apikey': OpenTrip_API,
    'kinds': wanted_kinds,
    'limit': 20,
    'rate': wanted_rates
}

response = requests.get(BASE_URL, params = params)
time.sleep(5)

# 如果程式狀態回應是200，那回應將會解析成json格式的數據，存在變數data中
if response.status_code == 200:
    data = response.json()
else:
    print('Status code:', response.status_code)


import pandas as pd
from pandas import json_normalize


# 將formatted_data存到data.json中
'''
with open('data.json', 'w', encoding = 'utf-8') as f:
    # json.dumps將程式作用的對象(像是字典、列表)進行格式化輸出
    formatted_data = json.dumps(data, indent = 4, sort_keys = True, ensure_ascii = False) # ensure_asscii = False 可確保中文正常顯示。

print('資料已成功儲存到data.json中')

# Validate your JSON
try:
    with open('data.json', 'r') as f:
        data = json.load(f)
    print('JSON is valid.')
except json.JSONDecodeError as e:
    print(f'JSON is malformed: {e}')
'''

# 使用pandas.json_normalized(當JSON包含嵌套結構時，需要將嵌套字段提取到DataFrame的列中時用)

df = pd.json_normalize(
    data,
    record_path = 'features'
)
print(df)

wanted_columns_df = df.loc[:, ['properties.name', 'properties.dist', 'properties.kinds', 'properties.rate', 'geometry.coordinates']]

# 改欄位名稱
wanted_columns_df.columns = ['name', 'dist', 'kinds', 'rate', 'point.lon/lat']

wanted_columns_df

# wanted_columns_df.to_csv('./df_cleaned.csv', index = 0, header = 1, encoding = 'utf-8')
# Out:
#        type        id geometry.type       geometry.coordinates properties.xid  \
# 0   Feature  15419293         Point  [121.5185852, 25.0483837]      Q24837584
# 1   Feature  14701688         Point   [121.515831, 25.0461121]      Q11104435
# 2   Feature  15827844         Point  [121.5153351, 25.0459385]        Q704778
# 3   Feature   7137212         Point   [121.5142517, 25.047678]     W204616539
# 4   Feature  11663300         Point  [121.5153351, 25.0449619]     W271425151
# 5   Feature  15565758         Point     [121.513588, 25.04669]      Q85877988
# 6   Feature  15621878         Point  [121.5201187, 25.0457592]      Q15914696
# 7   Feature  11593518         Point  [121.5190353, 25.0507717]     W217690234
# 8   Feature  14914069         Point  [121.5199966, 25.0452785]        Q702839
# 9   Feature  15144453         Point  [121.5127029, 25.0487003]       Q1495752
# 10  Feature  11706994         Point  [121.5147934, 25.0440903]     W247678979
# 11  Feature  11706995         Point  [121.5147705, 25.0440445]    N5762067188
# 12  Feature  11663299         Point  [121.5143585, 25.0441818]    N4762271318
# 13  Feature  11663296         Point  [121.5142746, 25.0441628]    N5762066922
# 14  Feature  11663291         Point  [121.5211334, 25.0448322]     W225875957
# 15  Feature  11685960         Point   [121.514389, 25.0436459]     W253142536
# 16  Feature  11286674         Point  [121.5195007, 25.0434551]     W192642995
# 17  Feature  11422628         Point  [121.5114212, 25.0470848]     W271754072
# 18  Feature  15372332         Point   [121.5175552, 25.042717]       Q1418766
# 19  Feature  11508527         Point  [121.5200806, 25.0522156]     W204211742
#
#                                       properties.name  properties.dist  \
# 0                             The World in Aves’ Eyes       172.583134
# 1                                 Asia Plaza Building       221.045136
# 2                                Shin Kong Life Tower       265.883152
# 3                                 Taipei Travel Plaza       277.358737
# 4                                      Bank of Taiwan       356.654725
# 5                                   Kee Tai Zhongxiao       365.416465
# 6                                               臺北市役所       387.743614
# 7                   Museum of Contemporary Art Taipei       388.173623
# 8                                        Control Yuan       411.959992
# 9                                  Taipei Twin Towers       445.221504
# 10                                Land Bank of Taiwan       467.376550
# 11                                Land Bank of Taiwan       472.791618
# 12                                Land Bank of Taiwan       481.450880
# 13                                Land Bank of Taiwan       487.962913
# 14                              Control Yuan Building       531.236384
# 15  Taiwan Land Bank Exhibition Hall, National Tai...       530.162036
# 16              Chè-lâm Presbyterian Church in Taiwan       543.599687
# 17                                 Taipei Post Office       568.254776
# 18                National Taiwan University Hospital       565.855190
# 19                                               菩提講堂       579.606479
#
#     properties.rate properties.wikidata  \
# 0                 3           Q24837584
# 1                 3           Q11104435
# 2                 3             Q704778
# 3                 3           Q42851039
# 4                 7           Q10901492
# 5                 3           Q85877988
# 6                 7           Q15914696
# 7                 7             Q699040
# 8                 7             Q702839
# 9                 3            Q1495752
# 10                7           Q10901492
# 11                7           Q10901492
# 12                7           Q10901492
# 13                7           Q10901492
# 14                7           Q15935432
# 15                7           Q10901492
# 16                7            Q7221055
# 17                7            Q7676310
# 18                7            Q1418766
# 19                3           Q10509150
#
#                                      properties.kinds   properties.osm
# 0   historic,cultural,urban_environment,monuments_...              NaN
# 1         skyscrapers,architecture,interesting_places              NaN
# 2         skyscrapers,architecture,interesting_places              NaN
# 3   urban_environment,gardens_and_parks,cultural,i...    way/204616539
# 4   architecture,historic_architecture,cultural,mu...    way/271425151
# 5         skyscrapers,architecture,interesting_places              NaN
# 6   historic_architecture,architecture,interesting...              NaN
# 7   cultural,museums,interesting_places,art_galleries    way/217690234
# 8   other,unclassified_objects,interesting_places,...              NaN
# 9         skyscrapers,architecture,interesting_places              NaN
# 10  architecture,historic_architecture,cultural,mu...    way/247678979
# 11  architecture,historic_architecture,cultural,mu...  node/5762067188
# 12  architecture,historic_architecture,cultural,mu...  node/4762271318
# 13  architecture,historic_architecture,cultural,mu...  node/5762066922
# 14  architecture,historic_architecture,interesting...    way/225875957
# 15  architecture,historic_architecture,cultural,mu...    way/253142536
# 16  religion,churches,interesting_places,other_chu...    way/192642995
# 17  architecture,historic_architecture,interesting...    way/271754072
# 18  historic_architecture,architecture,interesting...              NaN
# 19          religion,other_temples,interesting_places    way/204211742
#                                                  name        dist  \
# 0                             The World in Aves’ Eyes  172.583134
# 1                                 Asia Plaza Building  221.045136
# 2                                Shin Kong Life Tower  265.883152
# 3                                 Taipei Travel Plaza  277.358737
# 4                                      Bank of Taiwan  356.654725
# 5                                   Kee Tai Zhongxiao  365.416465
# 6                                               臺北市役所  387.743614
# 7                   Museum of Contemporary Art Taipei  388.173623
# 8                                        Control Yuan  411.959992
# 9                                  Taipei Twin Towers  445.221504
# 10                                Land Bank of Taiwan  467.376550
# 11                                Land Bank of Taiwan  472.791618
# 12                                Land Bank of Taiwan  481.450880
# 13                                Land Bank of Taiwan  487.962913
# 14                              Control Yuan Building  531.236384
# 15  Taiwan Land Bank Exhibition Hall, National Tai...  530.162036
# 16              Chè-lâm Presbyterian Church in Taiwan  543.599687
# 17                                 Taipei Post Office  568.254776
# 18                National Taiwan University Hospital  565.855190
# 19                                               菩提講堂  579.606479
#
#                                                 kinds  rate  \
# 0   historic,cultural,urban_environment,monuments_...     3
# 1         skyscrapers,architecture,interesting_places     3
# 2         skyscrapers,architecture,interesting_places     3
# 3   urban_environment,gardens_and_parks,cultural,i...     3
# 4   architecture,historic_architecture,cultural,mu...     7
# 5         skyscrapers,architecture,interesting_places     3
# 6   historic_architecture,architecture,interesting...     7
# 7   cultural,museums,interesting_places,art_galleries     7
# 8   other,unclassified_objects,interesting_places,...     7
# 9         skyscrapers,architecture,interesting_places     3
# 10  architecture,historic_architecture,cultural,mu...     7
# 11  architecture,historic_architecture,cultural,mu...     7
# 12  architecture,historic_architecture,cultural,mu...     7
# 13  architecture,historic_architecture,cultural,mu...     7
# 14  architecture,historic_architecture,interesting...     7
# 15  architecture,historic_architecture,cultural,mu...     7
# 16  religion,churches,interesting_places,other_chu...     7
# 17  architecture,historic_architecture,interesting...     7
# 18  historic_architecture,architecture,interesting...     7
# 19          religion,other_temples,interesting_places     3
#
#                 point.lon/lat
# 0   [121.5185852, 25.0483837]
# 1    [121.515831, 25.0461121]
# 2   [121.5153351, 25.0459385]
# 3    [121.5142517, 25.047678]
# 4   [121.5153351, 25.0449619]
# 5      [121.513588, 25.04669]
# 6   [121.5201187, 25.0457592]
# 7   [121.5190353, 25.0507717]
# 8   [121.5199966, 25.0452785]
# 9   [121.5127029, 25.0487003]
# 10  [121.5147934, 25.0440903]
# 11  [121.5147705, 25.0440445]
# 12  [121.5143585, 25.0441818]
# 13  [121.5142746, 25.0441628]
# 14  [121.5211334, 25.0448322]
# 15   [121.514389, 25.0436459]
# 16  [121.5195007, 25.0434551]
# 17  [121.5114212, 25.0470848]
# 18   [121.5175552, 25.042717]
# 19  [121.5200806, 25.0522156]
