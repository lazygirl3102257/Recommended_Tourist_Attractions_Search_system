# %%
# OpenTripMap API requests

import json
from dotenv import load_dotenv
load_dotenv()

import time
import os

OpenTrip_API = os.environ.get('OpenTripMap_API_key')

import requests

Base_url = 'https://api.opentripmap.com/0.1/en/places/radius'

params = {
    'radius': 1000,
    'lon': 121.5170,
    'lat': 25.0478,
    'apikey': OpenTrip_API,
    'format': 'json'
}

response = requests.get(Base_url, params = params)

print(response.status_code)
print(response.text)
# Out:
# 200
# {}

# %%
# TDX API requests


import requests
from pprint import pprint
import time
import json

from dotenv import load_dotenv
load_dotenv()

import os

TDX_API_ID = os.environ.get('TDX_APP_ID')
TDX_API_KEY = os.environ.get('TDX_API_KEY')

app_id = TDX_API_ID
app_key = TDX_API_KEY

auth_url = 'https://tdx.transportdata.tw/auth/realms/TDXConnect/protocol/openid-connect/token'
url = 'https://tdx.transportdata.tw/api/tourism/service/odata/V2/Tourism/Nearby?X=121.5170&Y=25.0478&Distance=1000&%24select=RelatedAttractions'

class Auth():
    def __init__(self, app_id, app_key):
        self.app_id = app_id
        self.app_key = app_key

    def get_auth_header(self):
        content_type = 'application/x-www-form-urlencoded'
        grant_type = 'client_credentials'

        return{
            'content_type': content_type,
            'grant_type': grant_type,
            'client_id': self.app_id,
            'client_secret': self.app_key
        }

class data():
    def __init__(self, app_id, app_key, auth_response):
        self.app_id = app_id
        self.app_key = app_key
        self.auth_response = auth_response

    def get_data_header(self):
        auth_JSON = json.loads(self.auth_response.text)
        access_token = auth_JSON.get('access_token')

        return{
            'authorization' : 'Bearer ' + access_token,
            'accept-Encoding' : 'gzip'
        }

if __name__ == '__main__':
    try:
        d = data(app_id, app_key, auth_response)
        data_response = requests.get(url, headers = d.get_data_header())
    except:
        a = Auth(app_id, app_key)
        auth_response = requests.post(auth_url, a.get_auth_header())
        d = data(app_id, app_key, auth_response)
        data_response = requests.get(url, headers = d.get_data_header())
    print(auth_response)
    pprint(auth_response.text)
    print(data_response)
    pprint(data_response.text)



with open('Taipei_station_attractions.json', 'w', encoding = 'utf-8') as f:
    json_data = json.loads(data_response.text)
    # json.dumps將程式作用的對象(像是字串、列表)進行格式化輸出
    formatted_data = json.dumps(json_data, indent = 4, sort_keys = True, ensure_ascii = False)
    f.write(formatted_data)

print(formatted_data)

with open('Taipei_station_attractions.json', 'r', encoding = 'utf-8') as f1:
    attractions_dict = json.load(f1)

print(type(attractions_dict))
print(attractions_dict)

attraction_list = attractions_dict['RelatedAttractions']
print(type(attraction_list))
print(attraction_list)

source_location = {
    'name': '台北車站',
    'Lat': 25.0478,
    'Lon': 121.5170
}

target_locations = attraction_list

from geopy.distance import geodesic

def get_distances(source_location, target_locations):
    results = [
        {
            'AttractionName': target_location['AttractionName'],
            'distance(km)': geodesic((source_location['Lat'], source_location['Lon']), (target_location['PositionLat'], target_location['PositionLon'])).kilometers
        }
        for target_location in target_locations
    ]
    return results

results = get_distances(source_location, target_locations)
print(results)

import pandas as pd

# 原始資料轉成DataFrame
df = pd.DataFrame(attraction_list)

# 計算距台北車站距離的結果資料轉成DataFrame
df1 = pd.DataFrame(results)

# 依據'AttractionName'欄位，合併以上2個DataFrame
final = pd.merge(df, df1, on = 'AttractionName')
final

# final.to_csv('attraction_distance_to_Taipei_station.csv', index = 0, header = 1, encoding = 'utf-8')
# Out:
# <Response [200]>
# ('{"access_token":"eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJER2lKNFE5bFg4WldFajlNNEE2amFVNm9JOGJVQ3RYWGV6OFdZVzh3ZkhrIn0.....o2sWXPURUsa4DunjyEMXaJDTKd4nBZ3LZZs8xfoU0lrxG5XhOyYvKlVEAPVE11461JD6nFz3nnN_8mgh0UXDngPjuY25MVWni5HdkXWkh10C6A0V4Mom4ONF6hOBdtxuu4adjNeVg97p_gieFk4C21r_BvxNw6wNtZfgOyhwGS4ZheFUwac_tctRHZGA63M4YTyRSGO2ywKk2Bxe5hhcBKQ3SZMiDODbaP50KVnqjTuL_qsErcRvQJ8Ei5ZVbOXgJihu7uOZvtIIq3lh5VwRbFdyNCAfavfXUI8fEcQbfRJqs3XfUID1cas-qOuBprPy6XgqVlCMZddjV6c1S95g_g","expires_in":86400,"refresh_expires_in":0,"token_type":"Bearer","not-before-policy":0,"scope":"profile '
#  'email"}')
# <Response [200]>
# ('{"RelatedAttractions":[{"AttractionID":"Attraction_379000000A_000104","AttractionName":"國立臺灣博物館","PositionLat":25.04276,"PositionLon":121.51503},{"AttractionID":"Attraction_379000000A_000137","AttractionName":"二二八和平公園","PositionLat":25.04132,"PositionLon":121.51516},{"AttractionID":"Attraction_379000000A_000141","AttractionName":"台北當代藝術館","PositionLat":25.05072,"PositionLon":121.51892},{"AttractionID":"Attraction_379000000A_000158","AttractionName":"SPOT光點台北電影館","PositionLat":25.05325,"PositionLon":121.52225},{"AttractionID":"Attraction_379000000A_000368","AttractionName":"北門_承恩門","PositionLat":25.04773,"PositionLon":121.51123},{"AttractionID":"Attraction_379000000A_000385","AttractionName":"國立臺灣大學醫學院附設醫院_西址","PositionLat":25.04199,"PositionLon":121.51722},{"AttractionID":"Attraction_379000000A_000387","AttractionName":"東門_景福門","PositionLat":25.03907,"PositionLon":121.51765},{"AttractionID":"Attraction_379000000A_000389","AttractionName":"台灣基督長老教會_中山教會","PositionLat":25.04903,"PositionLon":121.52438},{"AttractionID":"Attraction_379000000A_000394","AttractionName":"臺北賓館","PositionLat":25.04015,"PositionLon":121.51675},{"AttractionID":"Attraction_379000000A_000401","AttractionName":"臺北北門郵局_臺北901支","PositionLat":25.04692,"PositionLon":121.5114},{"AttractionID":"Attraction_379000000A_000588","AttractionName":"臺北市中山堂","PositionLat":25.04319,"PositionLon":121.50967},{"AttractionID":"Attraction_379000000A_001248","AttractionName":"國立臺灣大學博物館群_醫學人文博物館","PositionLat":25.03953,"PositionLon":121.51886},{"AttractionID":"Attraction_379000000A_001436","AttractionName":"蒲添生故居","PositionLat":25.04549,"PositionLon":121.52466},{"AttractionID":"Attraction_379000000A_001440","AttractionName":"建成圓環","PositionLat":25.05381,"PositionLon":121.51469},{"AttractionID":"Attraction_379000000A_001572","AttractionName":"國立臺灣博物館_古生物館","PositionLat":25.04356,"PositionLon":121.51436},{"AttractionID":"Attraction_379000000A_001574","AttractionName":"撫臺街洋樓 '
.054021,"PositionLon":121.512162},{"AttractionID":"Attraction_379000000A_003676","AttractionName":"臺北記憶倉庫(三井倉庫)","PositionLat":25.047697,"PositionLon":121.512426},{"AttractionID":"Attraction_379000000A_003677","AttractionName":"渭水驛站","PositionLat":25.05472,"PositionLon":121.511781},{"AttractionID":"Attraction_379000000A_003678","AttractionName":"白色恐怖政治受難者紀念碑","PositionLat":25.039508,"PositionLon":121.514129}]}')
# {
#     "RelatedAttractions": [
#         {
#             "AttractionID": "Attraction_379000000A_000104",
#             "AttractionName": "國立臺灣博物館",
#             "PositionLat": 25.04276,
#             "PositionLon": 121.51503
#         },
#         {
#             "AttractionID": "Attraction_379000000A_000137",
#             "AttractionName": "二二八和平公園",
#             "PositionLat": 25.04132,
#             "PositionLon": 121.51516
#         },
#         {
#             "AttractionID": "Attraction_379000000A_000141",
#             "AttractionName": "台北當代藝術館",
#             "PositionLat": 25.05072,
#             "PositionLon": 121.51892
#         },
#         {
#             "AttractionID": "Attraction_379000000A_000158",
#             "AttractionName": "SPOT光點台北電影館",
#             "PositionLat": 25.05325,
#             "PositionLon": 121.52225
#         },
#         {
#             "AttractionID": "Attraction_379000000A_000368",
#             "AttractionName": "北門_承恩門",
#             "PositionLat": 25.04773,
#             "PositionLon": 121.51123
#         },
#         {
#             "AttractionID": "Attraction_379000000A_000385",
#             "AttractionName": "國立臺灣大學醫學院附設醫院_西址",
#             "PositionLat": 25.04199,
#             "PositionLon": 121.51722
#         },
#         {
#             "AttractionID": "Attraction_379000000A_000387",
#             "AttractionName": "東門_景福門",
#             "PositionLat": 25.03907,
#             "PositionLon": 121.51765
#         },
#         {
#             "AttractionID": "Attraction_379000000A_000389",
#             "AttractionName": "台灣基督長老教會_中山教會",
#             "PositionLat": 25.04903,
#             "PositionLon": 121.52438
#         },
#         {
#             "AttractionID": "Attraction_379000000A_000394",
#             "AttractionName": "臺北賓館",
#             "PositionLat": 25.04015,
#             "PositionLon": 121.51675
#         },
#         {
#             "AttractionID": "Attraction_379000000A_000401",
#             "AttractionName": "臺北北門郵局_臺北901支",
#             "PositionLat": 25.04692,
#             "PositionLon": 121.5114
#         },
#         {
#             "AttractionID": "Attraction_379000000A_000588",
#             "AttractionName": "臺北市中山堂",
#             "PositionLat": 25.04319,
#             "PositionLon": 121.50967
#         },
#         {
#             "AttractionID": "Attraction_379000000A_001248",
#             "AttractionName": "國立臺灣大學博物館群_醫學人文博物館",
#             "PositionLat": 25.03953,
#             "PositionLon": 121.51886
#         },
#         {
#             "AttractionID": "Attraction_379000000A_001436",
#             "AttractionName": "蒲添生故居",
#             "PositionLat": 25.04549,
#             "PositionLon": 121.52466
#         },
#         {
#             "AttractionID": "Attraction_379000000A_001440",
#             "AttractionName": "建成圓環",
#             "PositionLat": 25.05381,
#             "PositionLon": 121.51469
#         },
#         {
#             "AttractionID": "Attraction_379000000A_001572",
#             "AttractionName": "國立臺灣博物館_古生物館",
#             "PositionLat": 25.04356,
#             "PositionLon": 121.51436
#         },
#         {
#             "AttractionID": "Attraction_379000000A_001574",
#             "AttractionName": "撫臺街洋樓 (《人民導報》舊址)",
#             "PositionLat": 25.04671,
#             "PositionLon": 121.51081
#         },
#         {
#             "AttractionID": "Attraction_379000000A_001865",
#             "AttractionName": "Art Space 金魚空間",
#             "PositionLat": 25.053532,
#             "PositionLon": 121.518553
#         },
#         {
#             "AttractionID": "Attraction_379000000A_001875",
#             "AttractionName": "非畫廊Beyond Gallery",
#             "PositionLat": 25.049806,
#             "PositionLon": 121.522432
#         },
#         {
#             "AttractionID": "Attraction_379000000A_002263",
#             "AttractionName": "赤峰街",
#             "PositionLat": 25.055346,
#             "PositionLon": 121.519607
#         },
#         {
#             "AttractionID": "Attraction_379000000A_002533",
#             "AttractionName": "臺北市交通資訊中心",
#             "PositionLat": 25.04925,
#             "PositionLon": 121.51873
#         },
#         {
#             "AttractionID": "Attraction_379000000A_002576",
#             "AttractionName": "國立臺灣博物館_鐵道部園區",
#             "PositionLat": 25.048834,
#             "PositionLon": 121.511383
#         },
#         {
#             "AttractionID": "Attraction_379000000A_002597",
#             "AttractionName": "臺灣省城隍廟",
#             "PositionLat": 25.04395,
#             "PositionLon": 121.51271
#         },
#         {
#             "AttractionID": "Attraction_379000000A_002641",
#             "AttractionName": "順益台灣原住民博物館_美術分館",
#             "PositionLat": 25.046377,
#             "PositionLon": 121.510951
#         },
#         {
#             "AttractionID": "Attraction_379000000A_002650",
#             "AttractionName": "城中市場",
#             "PositionLat": 25.043557,
#             "PositionLon": 121.512222
#         },
#         {
#             "AttractionID": "Attraction_379000000A_002994",
#             "AttractionName": "捷運北門站_台北鐵道局",
#             "PositionLat": 25.04954,
#             "PositionLon": 121.51018
#         },
#         {
#             "AttractionID": "Attraction_379000000A_003084",
#             "AttractionName": "陳德星堂",
#             "PositionLat": 25.05564,
#             "PositionLon": 121.51592
#         },
#         {
#             "AttractionID": "Attraction_379000000A_003109",
#             "AttractionName": "博愛路_漢口街_相機街",
#             "PositionLat": 25.04533,
#             "PositionLon": 121.51139
#         },
#         {
#             "AttractionID": "Attraction_379000000A_003111",
#             "AttractionName": "重慶南路_書店街",
#             "PositionLat": 25.04459,
#             "PositionLon": 121.51322
#         },
#         {
#             "AttractionID": "Attraction_379000000A_003113",
#             "AttractionName": "沅陵商店街_鞋子街",
#             "PositionLat": 25.042877,
#             "PositionLon": 121.512708
#         },
#         {
#             "AttractionID": "Attraction_379000000A_003122",
#             "AttractionName": "捷運中山地下書街_誠品R79",
#             "PositionLat": 25.054986,
#             "PositionLon": 121.520577
#         },
#         {
#             "AttractionID": "Attraction_379000000A_003148",
#             "AttractionName": "後站商圈",
#             "PositionLat": 25.05038,
#             "PositionLon": 121.51357
#         },
#         {
#             "AttractionID": "Attraction_379000000A_003153",
#             "AttractionName": "捷運中山站街區_心中山線形公園",
#             "PositionLat": 25.05582,
#             "PositionLon": 121.5206
#         },
#         {
#             "AttractionID": "Attraction_379000000A_003154",
#             "AttractionName": "中山北路條通商圈",
#             "PositionLat": 25.05165,
#             "PositionLon": 121.52264
#         },
#         {
#             "AttractionID": "Attraction_379000000A_003156",
#             "AttractionName": "台北地下街",
#             "PositionLat": 25.04956,
#             "PositionLon": 121.51389
#         },
#         {
#             "AttractionID": "Attraction_379000000A_003163",
#             "AttractionName": "臺鐵臺北車站",
#             "PositionLat": 25.04775,
#             "PositionLon": 121.51704
#         },
#         {
#             "AttractionID": "Attraction_379000000A_003169",
#             "AttractionName": "逸仙公園",
#             "PositionLat": 25.04774,
#             "PositionLon": 121.52007
#         },
#         {
#             "AttractionID": "Attraction_379000000A_003673",
#             "AttractionName": "國際書局(舊址)",
#             "PositionLat": 25.053777,
#             "PositionLon": 121.511891
#         },
#         {
#             "AttractionID": "Attraction_379000000A_003674",
#             "AttractionName": "天馬茶房",
#             "PositionLat": 25.054021,
#             "PositionLon": 121.512162
#         },
#         {
#             "AttractionID": "Attraction_379000000A_003676",
#             "AttractionName": "臺北記憶倉庫(三井倉庫)",
#             "PositionLat": 25.047697,
#             "PositionLon": 121.512426
#         },
#         {
#             "AttractionID": "Attraction_379000000A_003677",
#             "AttractionName": "渭水驛站",
#             "PositionLat": 25.05472,
#             "PositionLon": 121.511781
#         },
#         {
#             "AttractionID": "Attraction_379000000A_003678",
#             "AttractionName": "白色恐怖政治受難者紀念碑",
#             "PositionLat": 25.039508,
#             "PositionLon": 121.514129
#         }
#     ]
# }
# <class 'dict'>
# {'RelatedAttractions': [{'AttractionID': 'Attraction_379000000A_000104', 'AttractionName': '國立臺灣博物館', 'PositionLat': 25.04276, 'PositionLon': 121.51503}, {'AttractionID': 'Attraction_379000000A_000137', 'AttractionName': '二二八和平公園', 'PositionLat': 25.04132, 'PositionLon': 121.51516}, {'AttractionID': 'Attraction_379000000A_000141', 'AttractionName': '台北當代藝術館', 'PositionLat': 25.05072, 'PositionLon': 121.51892}, {'AttractionID': 'Attraction_379000000A_000158', 'AttractionName': 'SPOT光點台北電影館', 'PositionLat': 25.05325, 'PositionLon': 121.52225}, {'AttractionID': 'Attraction_379000000A_000368', 'AttractionName': '北門_承恩門', 'PositionLat': 25.04773, 'PositionLon': 121.51123}, {'AttractionID': 'Attraction_379000000A_000385', 'AttractionName': '國立臺灣大學醫學院附設醫院_西址', 'PositionLat': 25.04199, 'PositionLon': 121.51722}, {'AttractionID': 'Attraction_379000000A_000387', 'AttractionName': '東門_景福門', 'PositionLat': 25.03907, 'PositionLon': 121.51765}, {'AttractionID': 'Attraction_379000000A_000389', 'AttractionName': '台灣基督長老教會_中山教會', 'PositionLat': 25.04903, 'PositionLon': 121.52438}, {'AttractionID': 'Attraction_379000000A_000394', 'AttractionName': '臺北賓館', 'PositionLat': 25.04015, 'PositionLon': 121.51675}, {'AttractionID': 'Attraction_379000000A_000401', 'AttractionName': '臺北北門郵局_臺北901支', 'PositionLat': 25.04692, 'PositionLon': 121.5114}, {'AttractionID': 'Attraction_379000000A_000588', 'AttractionName': '臺北市中山堂', 'PositionLat': 25.04319, 'PositionLon': 121.50967}, {'AttractionID': 'Attraction_379000000A_001248', 'A
', 'distance(km)': 0.8752765287945878}, {'AttractionName': '博愛路_漢口街_相機街', 'distance(km)': 0.6287691075158316}, {'AttractionName': '重慶南路_書店街', 'distance(km)': 0.5214809531895308}, {'AttractionName': '沅陵商店街_鞋子街', 'distance(km)': 0.6964090539868917}, {'AttractionName': '捷運中山地下書街_誠品R79', 'distance(km)': 0.8740311966849257}, {'AttractionName': '後站商圈', 'distance(km)': 0.4488642726930315}, {'AttractionName': '捷運中山站街區_心中山線形公園', 'distance(km)': 0.9598054275389265}, {'AttractionName': '中山北路條通商圈', 'distance(km)': 0.7111904584454883}, {'AttractionName': '台北地下街', 'distance(km)': 0.3694589078534649}, {'AttractionName': '臺鐵臺北車站', 'distance(km)': 0.0068534538206896116}, {'AttractionName': '逸仙公園', 'distance(km)': 0.3098681314847894}, {'AttractionName': '國際書局(舊址)', 'distance(km)': 0.8391375889655213}, {'AttractionName': '天馬茶房', 'distance(km)': 0.8445263437416215}, {'AttractionName': '臺北記憶倉庫(三井倉庫)', 'distance(km)': 0.4617081024879797}, {'AttractionName': '渭水驛站', 'distance(km)': 0.9300289821459173}, {'AttractionName': '白色恐怖政治受難者紀念碑', 'distance(km)': 0.9631436630747788}]
#                     AttractionID      AttractionName  PositionLat  \
# 0   Attraction_379000000A_000104             國立臺灣博物館    25.042760
# 1   Attraction_379000000A_000137             二二八和平公園    25.041320
# 2   Attraction_379000000A_000141             台北當代藝術館    25.050720
# 3   Attraction_379000000A_000158         SPOT光點台北電影館    25.053250
# 4   Attraction_379000000A_000368              北門_承恩門    25.047730
# 5   Attraction_379000000A_000385    國立臺灣大學醫學院附設醫院_西址    25.041990
# 6   Attraction_379000000A_000387              東門_景福門    25.039070
# 7   Attraction_379000000A_000389       台灣基督長老教會_中山教會    25.049030
# 8   Attraction_379000000A_000394                臺北賓館    25.040150
# 9   Attraction_379000000A_000401       臺北北門郵局_臺北901支    25.046920
# 10  Attraction_379000000A_000588              臺北市中山堂    25.043190
# 11  Attraction_379000000A_001248  國立臺灣大學博物館群_醫學人文博物館    25.039530
# 12  Attraction_379000000A_001436               蒲添生故居    25.045490
# 13  Attraction_379000000A_001440                建成圓環    25.053810
# 14  Attraction_379000000A_001572        國立臺灣博物館_古生物館    25.043560
# 15  Attraction_379000000A_001574    撫臺街洋樓 (《人民導報》舊址)    25.046710
# 16  Attraction_379000000A_001865      Art Space 金魚空間    25.053532
# 17  Attraction_379000000A_001875   非畫廊Beyond Gallery    25.049806
# 18  Attraction_379000000A_002263                 赤峰街    25.055346
# 19  Attraction_379000000A_002533           臺北市交通資訊中心    25.049250
# 20  Attraction_379000000A_002576       國立臺灣博物館_鐵道部園區    25.048834
# 21  Attraction_379000000A_002597              臺灣省城隍廟    25.043950
# 22  Attraction_379000000A_002641     順益台灣原住民博物館_美術分館    25.046377
# 23  Attraction_379000000A_002650                城中市場    25.043557
# 24  Attraction_379000000A_002994         捷運北門站_台北鐵道局    25.049540
# 25  Attraction_379000000A_003084                陳德星堂    25.055640
# 26  Attraction_379000000A_003109         博愛路_漢口街_相機街    25.045330
# 27  Attraction_379000000A_003111            重慶南路_書店街    25.044590
# 28  Attraction_379000000A_003113           沅陵商店街_鞋子街    25.042877
# 29  Attraction_379000000A_003122      捷運中山地下書街_誠品R79    25.054986
# 30  Attraction_379000000A_003148                後站商圈    25.050380
# 31  Attraction_379000000A_003153     捷運中山站街區_心中山線形公園    25.055820
# 32  Attraction_379000000A_003154            中山北路條通商圈    25.051650
# 33  Attraction_379000000A_003156               台北地下街    25.049560
# 34  Attraction_379000000A_003163              臺鐵臺北車站    25.047750
# 35  Attraction_379000000A_003169                逸仙公園    25.047740
# 36  Attraction_379000000A_003673            國際書局(舊址)    25.053777
# 37  Attraction_379000000A_003674                天馬茶房    25.054021
# 38  Attraction_379000000A_003676        臺北記憶倉庫(三井倉庫)    25.047697
# 39  Attraction_379000000A_003677                渭水驛站    25.054720
# 40  Attraction_379000000A_003678        白色恐怖政治受難者紀念碑    25.039508
#
#     PositionLon  distance(km)
# 0    121.515030      0.592637
# 1    121.515160      0.741439
# 2    121.518920      0.377046
# 3    121.522250      0.803200
# 4    121.511230      0.582308
# 5    121.517220      0.643977
# 6    121.517650      0.969275
# 7    121.524380      0.757081
# 8    121.516750      0.847793
# 9    121.511400      0.573450
# 10   121.509670      0.898846
# 11   121.518860      0.935129
# 12   121.524660      0.814239
# 13   121.514690      0.705378
# 14   121.514360      0.539975
# 15   121.510810      0.636205
# 16   121.518553      0.654007
# 17   121.522432      0.591473
# 18   121.519607      0.876316
# 19   121.518730      0.237225
# 20   121.511383      0.578272
# 21   121.512710      0.607700
# 22   121.510951      0.630439
# 23   121.512222      0.673343
# 24   121.510180      0.714690
# 25   121.515920      0.875277
# 26   121.511390      0.628769
# 27   121.513220      0.521481
# 28   121.512708      0.696409
# 29   121.520577      0.874031
# 30   121.513570      0.448864
# 31   121.520600      0.959805
# 32   121.522640      0.711190
# 33   121.513890      0.369459
# 34   121.517040      0.006853
# 35   121.520070      0.309868
# 36   121.511891      0.839138
# 37   121.512162      0.844526
# 38   121.512426      0.461708
# 39   121.511781      0.930029
# 40   121.514129      0.963144

# %%
import folium
import pandas as pd
from folium.plugins import MarkerCluster



# 以台北車站為中心
center_lat, center_lon = 25.0478, 121.5170
m = folium.Map(location = [center_lat, center_lon], zoom_start = 15)

# 台北車站(圓心)特別標示
folium.CircleMarker(
    location = [center_lat, center_lon],
    radius = 10, # 大小較大
    popup = '台北車站(圓心)',
    color = 'red',
    fill = True,
    fill_color = 'red',
    fill_cpacity = 0.9).add_to(m)
                                           

# 加上其他景點(用MarkerCluster管理)
Attraction_df = pd.read_csv('./attraction_distance_to_Taipei_station.csv', encoding = 'utf-8')

marker_cluster = MarkerCluster().add_to(m)

for idx, row in Attraction_df.iterrows():
    folium.CircleMarker(
    location = [row['PositionLat'], row['PositionLon']],
    radius = 4,
    color = 'blue',
    fill = True,
    fill_color = 'blue',
    fill_opacity = 0.6,
    popup = row['AttractionName']
).add_to(marker_cluster)

m
m.save('map_with_center_highlight.html')
